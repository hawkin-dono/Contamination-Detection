# %%
from pathlib import Path

import numpy as np
import pandas as pd

# %%
DIRECTORY = Path(r'C:\Users\Admin\Desktop\Contamination-Detection\logging_file\mask_half_question')

# %%
data_list = list(DIRECTORY.iterdir())
data_list
# Out:
# [WindowsPath('C:/Users/Admin/Desktop/Contamination-Detection/logging_file/mask_half_question/gemma-2-2b+domain_mask_half_question'),
#  WindowsPath('C:/Users/Admin/Desktop/Contamination-Detection/logging_file/mask_half_question/gemma-2-2b+mmlu_mask_half_question'),
#  WindowsPath('C:/Users/Admin/Desktop/Contamination-Detection/logging_file/mask_half_question/gemma-2-2b+vmlu_mask_half_question'),
#  WindowsPath('C:/Users/Admin/Desktop/Contamination-Detection/logging_file/mask_half_question/gemma-2-9B+domain_mask_half_question'),
#  WindowsPath('C:/Users/Admin/Desktop/Contamination-Detection/logging_file/mask_half_question/gemma-2-9B+mmlu_mask_half_question'),
#  WindowsPath('C:/Users/Admin/Desktop/Contamination-Detection/logging_file/mask_half_question/gemma-2-9B+vmlu_mask_half_question'),
#  WindowsPath('C:/Users/Admin/Desktop/Contamination-Detection/logging_file/mask_half_question/Llama-3.1+domain_mask_half_question'),
# ...

# %%
TARGET = Path(r'C:\Users\Admin\Desktop\Contamination-Detection\logging_file\mask_half_question_data')
for folder in data_list:
    if folder.is_dir():
        print(folder)
        df = pd.read_csv(folder / 'result.csv')
        df.to_csv(TARGET / f'{folder.name}.csv', index=False)
# Out:
# C:\Users\Admin\Desktop\Contamination-Detection\logging_file\mask_half_question\gemma-2-2b+mmlu_mask_half_question
# C:\Users\Admin\Desktop\Contamination-Detection\logging_file\mask_half_question\gemma-2-2b+vmlu_mask_half_question
# C:\Users\Admin\Desktop\Contamination-Detection\logging_file\mask_half_question\gemma-2-9B+domain_mask_half_question
# C:\Users\Admin\Desktop\Contamination-Detection\logging_file\mask_half_question\gemma-2-9B+mmlu_mask_half_question
# C:\Users\Admin\Desktop\Contamination-Detection\logging_file\mask_half_question\gemma-2-9B+vmlu_mask_half_question
# C:\Users\Admin\Desktop\Contamination-Detection\logging_file\mask_half_question\Llama-3.1+domain_mask_half_question
# C:\Users\Admin\Desktop\Contamination-Detection\logging_file\mask_half_question\Llama-3.1+mmlu_mask_half_question
# C:\Users\Admin\Desktop\Contamination-Detection\logging_file\mask_half_question\Llama-3.1+vmlu_mask_half_question
# ...

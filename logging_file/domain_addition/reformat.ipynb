# %%
from pathlib import Path

import numpy as np
import pandas as pd

# %%
DIRECTORY = Path(r'C:\Users\Admin\Desktop\Contamination-Detection\logging_file\domain_addition')

# %%
data_list = list(DIRECTORY.iterdir())
data_list
# Out:
# [WindowsPath('C:/Users/Admin/Desktop/Contamination-Detection/logging_file/domain_addition/gemma-2-2b+domain_addition_mask_wrong_answer'),
#  WindowsPath('C:/Users/Admin/Desktop/Contamination-Detection/logging_file/domain_addition/gemma-2-9b-it+domain_addition_mask_wrong_answer'),
#  WindowsPath('C:/Users/Admin/Desktop/Contamination-Detection/logging_file/domain_addition/Meta-Llama-3.1-8B-Instruct+domain_addition_mask_wrong_answer'),
#  WindowsPath('C:/Users/Admin/Desktop/Contamination-Detection/logging_file/domain_addition/Phi-3.5-mini-instruct+domain_addition_mask_wrong_answer'),
#  WindowsPath('C:/Users/Admin/Desktop/Contamination-Detection/logging_file/domain_addition/Qwen2-7B-Instruct+domain_addition_mask_wrong_answer'),
#  WindowsPath('C:/Users/Admin/Desktop/Contamination-Detection/logging_file/domain_addition/reformat.ipynb'),
#  WindowsPath('C:/Users/Admin/Desktop/Contamination-Detection/logging_file/domain_addition/Vistral-7B-Chat+domain_addition_mask_wrong_answer')]

# %%
TARGET = Path(r'C:\Users\Admin\Desktop\Contamination-Detection\logging_file\domain_addition_data')
for folder in data_list:
    if folder.is_dir():
        print(folder)
        df = pd.read_csv(folder / 'result.csv')
        df.to_csv(TARGET / f'{folder.name}.csv', index=False)
# Out:
# C:\Users\Admin\Desktop\Contamination-Detection\logging_file\domain_addition\gemma-2-2b+domain_addition_mask_wrong_answer
# C:\Users\Admin\Desktop\Contamination-Detection\logging_file\domain_addition\gemma-2-9b-it+domain_addition_mask_wrong_answer
# C:\Users\Admin\Desktop\Contamination-Detection\logging_file\domain_addition\Meta-Llama-3.1-8B-Instruct+domain_addition_mask_wrong_answer
# C:\Users\Admin\Desktop\Contamination-Detection\logging_file\domain_addition\Phi-3.5-mini-instruct+domain_addition_mask_wrong_answer
# C:\Users\Admin\Desktop\Contamination-Detection\logging_file\domain_addition\Qwen2-7B-Instruct+domain_addition_mask_wrong_answer
# C:\Users\Admin\Desktop\Contamination-Detection\logging_file\domain_addition\Vistral-7B-Chat+domain_addition_mask_wrong_answer

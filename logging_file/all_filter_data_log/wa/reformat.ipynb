# %%
from pathlib import Path

import numpy as np
import pandas as pd

# %%
DIRECTORY = Path(r'C:\Users\Admin\Desktop\Contamination-Detection\logging_file\all_filter_data_log\wa_csv')

# %%
data_list = list(DIRECTORY.glob("*.csv"))
data_list
# Out:
# [WindowsPath('C:/Users/Admin/Desktop/Contamination-Detection/logging_file/all_filter_data_log/wa_csv/gemma-2-2b-it+all_filter_data_mask_wrong_answer.csv'),
#  WindowsPath('C:/Users/Admin/Desktop/Contamination-Detection/logging_file/all_filter_data_log/wa_csv/gemma-2-9b-it+all_filter_data_mask_wrong_answer.csv'),
#  WindowsPath('C:/Users/Admin/Desktop/Contamination-Detection/logging_file/all_filter_data_log/wa_csv/Meta-Llama-3.1-8B-Instruct+all_filter_data_mask_wrong_answer.csv'),
#  WindowsPath('C:/Users/Admin/Desktop/Contamination-Detection/logging_file/all_filter_data_log/wa_csv/Phi-3.5-mini-instruct+all_filter_data_mask_wrong_answer.csv'),
#  WindowsPath('C:/Users/Admin/Desktop/Contamination-Detection/logging_file/all_filter_data_log/wa_csv/Qwen2-7B-Instruct+all_filter_data_mask_wrong_answer.csv'),
#  WindowsPath('C:/Users/Admin/Desktop/Contamination-Detection/logging_file/all_filter_data_log/wa_csv/Vistral-7B-Chat+all_filter_data_mask_wrong_answer.csv')]

# %%
grade = pd.read_csv(r'C:\Users\Admin\Desktop\Contamination-Detection\logging_file\all_filter_data.csv')
grade = grade['Grade']
grade
# Out:
# 0        Văn 11
# 1        Văn 11
# 2        Văn 11
# 3        Văn 11
# 4        Văn 11
#          ...
# 1252    Toán 12
# 1253    Toán 12
# 1254    Toán 12
# 1255    Toán 12
# 1256    Toán 12
# Name: Grade, Length: 1257, dtype: object

# %%
for data in data_list:
    df = pd.read_csv(data)
    df['Grade'] = grade
    df.to_csv(data, index=False)

# %%
TARGET = Path(r'C:\Users\Admin\Desktop\Contamination-Detection\logging_file\all_filter_data_log\wa_csv')
TARGET.mkdir(exist_ok=True)
for folder in data_list:
    if folder.is_dir():
        print(folder)
        df = pd.read_csv(folder / 'result.csv')
        df.to_csv(TARGET / f'{folder.name}.csv', index=False)
# Out:
# C:\Users\Admin\Desktop\Contamination-Detection\logging_file\all_filter_data_log\wa\gemma-2-2b-it+all_filter_data_mask_wrong_answer
# C:\Users\Admin\Desktop\Contamination-Detection\logging_file\all_filter_data_log\wa\gemma-2-9b-it+all_filter_data_mask_wrong_answer
# C:\Users\Admin\Desktop\Contamination-Detection\logging_file\all_filter_data_log\wa\Meta-Llama-3.1-8B-Instruct+all_filter_data_mask_wrong_answer
# C:\Users\Admin\Desktop\Contamination-Detection\logging_file\all_filter_data_log\wa\Phi-3.5-mini-instruct+all_filter_data_mask_wrong_answer
# C:\Users\Admin\Desktop\Contamination-Detection\logging_file\all_filter_data_log\wa\Qwen2-7B-Instruct+all_filter_data_mask_wrong_answer
# C:\Users\Admin\Desktop\Contamination-Detection\logging_file\all_filter_data_log\wa\Vistral-7B-Chat+all_filter_data_mask_wrong_answer

# %%
test = pd.read_csv(r'C:\Users\Admin\Desktop\Contamination-Detection\logging_file\all_filter_data_log\wa_csv\filtered_data\Vistral-7B-Chat+all_filter_data_mask_wrong_answer.csv')
test[(test['Grade'] == 'Vật lý 12') & (test['retained'] == False)]
# Out:
#                                               Question  \
# 825  Dựa vào trí nhớ của bạn về các bộ dữ liệu, hãy...
# 826  Dựa vào trí nhớ của bạn về các bộ dữ liệu, hãy...
# 830  Dựa vào trí nhớ của bạn về các bộ dữ liệu, hãy...
# 831  Dựa vào trí nhớ của bạn về các bộ dữ liệu, hãy...
# 832  Dựa vào trí nhớ của bạn về các bộ dữ liệu, hãy...
# 833  Dựa vào trí nhớ của bạn về các bộ dữ liệu, hãy...
# 834  Dựa vào trí nhớ của bạn về các bộ dữ liệu, hãy...
# 835  Dựa vào trí nhớ của bạn về các bộ dữ liệu, hãy...
# 838  Dựa vào trí nhớ của bạn về các bộ dữ liệu, hãy...
# 839  Dựa vào trí nhớ của bạn về các bộ dữ liệu, hãy...
# 840  Dựa vào trí nhớ của bạn về các bộ dữ liệu, hãy...
# 841  Dựa vào trí nhớ của bạn về các bộ dữ liệu, hãy...
# 842  Dựa vào trí nhớ của bạn về các bộ dữ liệu, hãy...
# 843  Dựa vào trí nhớ của bạn về các bộ dữ liệu, hãy...
# 844  Dựa vào trí nhớ của bạn về các bộ dữ liệu, hãy...
# 845  Dựa vào trí nhớ của bạn về các bộ dữ liệu, hãy...
# ...

# %%
import pandas as pd

# %%
path = "vmlu_masked_wrong_answer.csv"

# %%
df = pd.read_csv(path)

# %%
df
# Out:
#                                                Question  \
# 0     Hãy điền vào trong dấu [] tại lựa chọn B dựa v...
# 1     Hãy điền vào trong dấu [] tại lựa chọn C dựa v...
# 2     Hãy điền vào trong dấu [] tại lựa chọn B dựa v...
# 3     Hãy điền vào trong dấu [] tại lựa chọn D dựa v...
# 4     Hãy điền vào trong dấu [] tại lựa chọn C dựa v...
# ...                                                 ...
# 9423  Hãy điền vào trong dấu [] tại lựa chọn B dựa v...
# 9424  Hãy điền vào trong dấu [] tại lựa chọn B dựa v...
# 9425  Hãy điền vào trong dấu [] tại lựa chọn D dựa v...
# 9426  Hãy điền vào trong dấu [] tại lựa chọn C dựa v...
# 9427  Hãy điền vào trong dấu [] tại lựa chọn A dựa v...
#
#                                                   Label Choosed_wrong_answer
# 0     B. Không còn thất nghiệp nhưng có thể còn lạm ...                    B
# 1           C. Không can thiệp vào thị trường ngoại hối                    C
# ...

# %%
df["Question"] = df["Question"].astype(str)
df["Label"] = df["Label"].astype(str)

# %%
df["Choosed_wrong_answer"] = df["Choosed_wrong_answer"].astype(str)
df["Choosed_wrong_answer"] = df["Choosed_wrong_answer"].astype(str)

# %%
df.to_csv(path, index=False)
